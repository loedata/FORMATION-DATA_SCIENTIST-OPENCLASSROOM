# %% [markdown]
# # <span class="bg-primary">16. COURS - ENTRAINER MODELE PREDICTIF LINEAIRE</span>

# %% [markdown]
# # <span class="bg-info">REGRESSION LINEAIRE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">MAXIMISATION DE LA VRAISEMBLANCE</span>

# %%
# dans un contexte bayésien, nous allons réfléchir en termes de probabilités et
# chercher les valeurs de β0,β1,…,βp pour lesquelles il est le plus 
# vraisemblable d'observer les données {X,y} qui nous sont données.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">METHODE DES MOINDRES CARRES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LIMITATIONS DE LA REGRESSION LINEAIRE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">REGULARISATION</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">CHOIX DU COEFFICIENT DE REGULARISATION</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">REDUIRE L'AMPLITUDE DES POIDS AFFECTES A VOS VARAIBLES</span>

# %% [markdown]
# # REGULARISATION DE TYKHONOV

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SOLUTION DE LA REGRESSION RIDGE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">IMPORTANCE DE LA STANDARDISATION DES VARIABLES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">CHEMIN DE REGULARISATION</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LASSO</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">ELASTIC NET</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
