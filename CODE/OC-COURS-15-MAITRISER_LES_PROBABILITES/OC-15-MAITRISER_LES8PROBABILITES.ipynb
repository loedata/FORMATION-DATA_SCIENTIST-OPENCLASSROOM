# %% [markdown]
# # <span class="bg-primary">15. MAITRISER LES PROBABILITES</span>

# %% [markdown]
# # <span class="bg-info">EXPERIENCE ALEATOIRE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ex : dés - on ne peut avoir que {1,2,3,4,5,6}

# %% [markdown]
# # <span class="bg-info">UNIVERS</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ex : dés - {1}, {3,6}, {2, 4, 6} ...

# %% [markdown]
# # <span class="bg-info">ENSEMBLE DES PARTIES D'UN SOUS-ENSEMBLE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # EVENEMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ex : dés  évenement 1 {3, 6} = ensemble des mutiples de 3, {2, 4, 6} pairs..

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">OPERATIONS SUR LES EVENEMENTS</span>

# %% [markdown]
# # INTERSECTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # UNION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # EVENEMENT CONTRAIRE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">PROBABILITE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">CARDINAL D'UN ENSEMBLE FINI</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">EQUIPROBABILITE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">PROPRIETES DE LA PROBABILITE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">PROBABILITE CONDITIONNELLE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ex prob cond : dés : probabilité d'avoir 4 si le dé affiche un nombre impair?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">SYSTEME COMPLET D'EVENEMENT</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">FORMULE DES PROBABILITES TOTALES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">INDEPENDANCE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIABLES ALEATOIRES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">SUPPORT D'UNE VARIABLE ALEATOIRE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIABLE ALEATOIRE DISCRETE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIABLE ALEATOIRE CONTINUE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">EVENEMENT LIE A UNE VARIABLE ALEATOIRE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOI DE PROBABILITE D'UNE VARIABLE ALEATOIRE DISCRETE (VAD)</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">FONCTION DE REPARTITION D'UNE VAD</span>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <span class="bg-info">PROPRIETES CARACTERISTIQUES D'UNE FONCTION DE REPARTITION D'UNE VAD</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">ESPERANCE D'UNE VAD</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">ESPERANCE D'UNE VAD POUR SUPPORT FINI</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIANCE D'UNE VAD</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIABLE ALEATOIRE CONTINUE (VAC)</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">FONCTION DE REPARTITION</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">DENSITE DE PROBABILITE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">ESPERANCE D'UNE VAC</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">VARIANCE D'UNE VAC</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">QUELQUES LOIS DISCRETES FINIES</span>

# %% [markdown]
# # <span class="bg-info">LOI UNIFORME</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOI DE BERNOUILLI DE PARAMETRE P</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOI BINOMIALE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">QUELQUES LOIS DISCRETES INFINIES</span>

# %% [markdown]
# # <span class="bg-info">LOIS GEOMETRIQUES DE PARAMETRE P</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOI DE POISSON DE PARAMETRE LAMBDA</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOIS UNIFORMES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOIS EXPONENTIELLES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOIS NORMALES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">COUPLE DE VARIABLES ALEATOIRES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">LOI D'UN COUPLE DE VARIABLES ALEATOIRES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">INDEPENDANCE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">ESPERANCE</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">COUPLE DE VARIABLED ALEATOIRES DISCRETES</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">COVARIANCE DE 2 VAD</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">CORRELATION</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span class="bg-info">INDEPENDANCE DE 2 VAD</span>

# %% [markdown]
# ![image.png](attachment:image.png)
